# %% [markdown]
# # 1.1 Importing Dependancies to Project

# %%
import numpy as np 
import pandas as pd
import tensorflow as tf 
import os
import cv2
import matplotlib as mpl
from matplotlib import pyplot as plt
import random
import time

# %%
os.listdir()
dataFolder = 'data'

for folder in os.listdir(dataFolder):

  print(folder)
# Out:
# Jacob_Hendrik_Pierneef
# Modern_Contemporary
# Impression_Expression

# %%
imageFeatures_df = pd.DataFrame()
imagePath_df = pd.DataFrame()

imagePath = []
csvPathList = []
folderName = []
fileName = id

for folder in os.listdir(dataFolder):
  folderPath = os.path.join(dataFolder,folder)
  for image in os.listdir(folderPath):
    imageID_Path = os.path.join(folderPath, image)
    if (imageID_Path[len(imageID_Path)-4:] == 'JPEG'): 
      imagePath.append(imageID_Path)
      

  for i in imagePath:
    # print(i)
    # print('Folder: ', i.split('/')[1:3], 'File: ', i.split('/')[2])


    # if(imagePath
    # imagePath_df = pd.DataFrame({'ID':[n.split('.')[0] for n in imageID_Path],
    #                             'Path':[folder+'/' + n for n in imageID_Path]})
    # print(csvPath)

for folder in os.listdir(dataFolder):
  folderPath = os.path.join(dataFolder,folder)
  csvPath = os.path.join(folderPath, 'data.csv')
  csvPathList.append(csvPath)

  #   # imageID_Path = os.listdir(folder)
  #   # imagePath_df = pd.DataFrame({'ID':[n.split('.')[0] for n in imageID_Path],
  #   #                             'Path':[folder+'/' + n for n in imageID_Path]})
  #   # csv_dataPath = os.path.join(folder,'data.csv')
  #   # imageFeatures_df = pd.concat(pd.read_csv(csv_dataPath, sep=','))
# Out:
# data\Jacob_Hendrik_Pierneef\0.JPEG
# data\Jacob_Hendrik_Pierneef\1.JPEG
# data\Jacob_Hendrik_Pierneef\10.JPEG
# data\Jacob_Hendrik_Pierneef\11.JPEG
# data\Jacob_Hendrik_Pierneef\12.JPEG
# data\Jacob_Hendrik_Pierneef\13.JPEG
# data\Jacob_Hendrik_Pierneef\14.JPEG
# data\Jacob_Hendrik_Pierneef\15.JPEG
# data\Jacob_Hendrik_Pierneef\16.JPEG
# data\Jacob_Hendrik_Pierneef\17.JPEG
# data\Jacob_Hendrik_Pierneef\18.JPEG
# data\Jacob_Hendrik_Pierneef\19.JPEG
# data\Jacob_Hendrik_Pierneef\2.JPEG
# data\Jacob_Hendrik_Pierneef\20.JPEG
# data\Jacob_Hendrik_Pierneef\21.JPEG
# data\Jacob_Hendrik_Pierneef\22.JPEG
# data\Jacob_Hendrik_Pierneef\23.JPEG
# data\Jacob_Hendrik_Pierneef\24.JPEG
# data\Jacob_Hendrik_Pierneef\25.JPEG
# data\Jacob_Hendrik_Pierneef\26.JPEG
# data\Jacob_Hendrik_Pierneef\27.JPEG
# data\Jacob_Hendrik_Pierneef\28.JPEG
# data\Jacob_Hendrik_Pierneef\29.JPEG
# data\Jacob_Hendrik_Pierneef\3.JPEG
# data\Jacob_Hendrik_Pierneef\30.JPEG
# data\Jacob_Hendrik_Pierneef\31.JPEG
# data\Jacob_Hendrik_Pierneef\32.JPEG
# data\Jacob_Hendrik_Pierneef\33.JPEG
# data\Impression_Expression\44.JPEG
# data\Impression_Expression\45.JPEG
# data\Impression_Expression\46.JPEG
# data\Impression_Expression\47.JPEG
# data\Impression_Expression\48.JPEG
# data\Impression_Expression\49.JPEG
# data\Impression_Expression\5.JPEG
# data\Impression_Expression\50.JPEG
# data\Impression_Expression\51.JPEG
# data\Impression_Expression\52.JPEG
# data\Impression_Expression\53.JPEG
# data\Impression_Expression\54.JPEG
# data\Impression_Expression\55.JPEG
# data\Impression_Expression\56.JPEG
# data\Impression_Expression\57.JPEG
# data\Impression_Expression\58.JPEG
# data\Impression_Expression\59.JPEG
# data\Impression_Expression\6.JPEG
# data\Impression_Expression\60.JPEG
# data\Impression_Expression\61.JPEG
# data\Impression_Expression\62.JPEG
# data\Impression_Expression\63.JPEG
# data\Impression_Expression\64.JPEG
# data\Impression_Expression\65.JPEG
# data\Impression_Expression\66.JPEG
# data\Impression_Expression\67.JPEG
# data\Impression_Expression\68.JPEG
# data\Impression_Expression\69.JPEG
# data\Impression_Expression\7.JPEG
# data\Impression_Expression\70.JPEG
# data\Impression_Expression\71.JPEG
# data\Impression_Expression\72.JPEG
# data\Impression_Expression\73.JPEG
# data\Impression_Expression\74.JPEG
# data\Impression_Expression\75.JPEG
# data\Impression_Expression\76.JPEG
# data\Impression_Expression\77.JPEG
# data\Impression_Expression\78.JPEG
# data\Impression_Expression\79.JPEG
# data\Impression_Expression\8.JPEG
# data\Impression_Expression\80.JPEG
# data\Impression_Expression\81.JPEG
# data\Impression_Expression\82.JPEG
# data\Impression_Expression\83.JPEG
# data\Impression_Expression\84.JPEG
# data\Impression_Expression\85.JPEG
# data\Impression_Expression\86.JPEG
# data\Impression_Expression\9.JPEG

# %%
csvDataFrame=[]
for i in csvPathList:
    print(i)
    csvDataFrame.append(pd.read_csv(i,sep=',') )

bigBoyfeatures_df = pd.concat(csvDataFrame, ignore_index=True)
bigBoyImages_df = pd.DataFrame(imagePath, columns=['Path'])
# Out:
# data\Jacob_Hendrik_Pierneef\data.csv
# data\Modern_Contemporary\data.csv
# data\Impression_Expression\data.csv

# %%
folderList = []
imageList = []

for i, row in bigBoyImages_df.iterrows():

    path = row['Path']
    path = path.split("\\")[1:]
    folderList.append(path[0])
    imageList.append(path[1])

bigBoyImages_df['Folder'] = pd.Series(folderList)
bigBoyImages_df['Image in Folder '] = pd.Series(imageList)

# %%
len(bigBoyfeatures_df)
# Out:
# 451

# %%
bigBoyImages_df.head()
# Out:
#                                   Path                  Folder  \
# 0   data\Jacob_Hendrik_Pierneef\0.JPEG  Jacob_Hendrik_Pierneef
# 1   data\Jacob_Hendrik_Pierneef\1.JPEG  Jacob_Hendrik_Pierneef
# 2  data\Jacob_Hendrik_Pierneef\10.JPEG  Jacob_Hendrik_Pierneef
# 3  data\Jacob_Hendrik_Pierneef\11.JPEG  Jacob_Hendrik_Pierneef
# 4  data\Jacob_Hendrik_Pierneef\12.JPEG  Jacob_Hendrik_Pierneef
#
#   Image in Folder
# 0           0.JPEG
# 1           1.JPEG
# 2          10.JPEG
# 3          11.JPEG
# 4          12.JPEG

# %% [markdown]
# # 1.2 Accesing List Directoriees and Creating Path Data Frame

# %%
os.listdir()



imageID_Path = os.listdir('Impression_Expression')
imagePath_df = pd.DataFrame({'ID':[n.split('.')[0] for n in imageID_Path],
                                'Path':[folder+'/' + n for n in imageID_Path]})

csv_dataPath = os.path.join('Impression_Expression','data.csv')
imageFeatures_df = pd.read_csv(csv_dataPath, sep=',')

# imageID[:}
# 

imagePath_df["ID"]= pd.to_numeric(imagePath_df["ID"],errors='coerce')

imagePath_df.reset_index(inplace=True)


for i,row in imagePath_df.iterrows():
    picture_Path = row['Path']
    # print(picture_Path)
    extCheck = len(picture_Path)
    path = picture_Path[extCheck-4:]
    if (path != 'JPEG'):
        imagePath_df.drop(i, inplace=True)


imagePath_df.drop(['index'], inplace=True, axis=1)

print(imagePath_df.head(),'\n')
# print(imageFeatures_df.head(), '\n')

print(len(imagePath_df))

# print(len(merged_df))

## Random Image
# Out:
#       ID                           Path
# 0   67.0  Impression_Expression/67.JPEG
# 5   59.0  Impression_Expression/59.JPEG
# 9   16.0  Impression_Expression/16.JPEG
# 10  58.0  Impression_Expression/58.JPEG
# 15  17.0  Impression_Expression/17.JPEG
#
# 87

# %% [markdown]
# # 1.3 - Merging CSV Data and File Paths According to ID

# %%
merged_df = pd.merge(left=imagePath_df, right=imageFeatures_df, on='ID', how='inner', )

# merged_df = merged_df.drop('Size'
# merged_df = merged_df.drop(['Medium', 'Size' ],  axis=1, )


print(merged_df.head())
# print(merged_df.tail())
print(len(merged_df))
# Out:
#      ID                           Path                Artist  \
# 0  67.0  Impression_Expression/67.JPEG          Errol Boyley
# 1  59.0  Impression_Expression/59.JPEG  Richard Hayley Lever
# 2  16.0  Impression_Expression/16.JPEG      Blessing Ngobeni
# 3  58.0  Impression_Expression/58.JPEG       Adriaan Boshoff
# 4  17.0  Impression_Expression/17.JPEG         David Koloane
#
#    Low Estimation Price  High Estimation Price Hammer Price  \
# 0                 810.0                 1080.0        918.0
# 1                 540.0                  810.0        864.0
# 2                 810.0                 1080.0        810.0
# 3                1620.0                 2160.0       1620.0
# 4                 540.0                  810.0        648.0
#
#                              Size                            Medium
# 0      50cm-75cm(19.68in-29.53in)  Oil on canvas laid down on board
# 1    27cm-34.5cm(10.63in-13.58in)                     Oil on canvas
# 2      58cm-42cm(22.83in-16.54in)               Lithograph on paper
# 3     24cm-34.5cm(9.45in-13.58in)  Oil on canvas laid down on board
# 4  36.5cm-57.5cm(14.37in-22.64in)                 Monotype on paper
# 87

# %% [markdown]
# # 1.3 Fixing Contents of Array and Dropping Unnecessary Data

# %%
## Validating the data

for i, row in merged_df.iterrows():
    if(merged_df.loc[i, 'Hammer Price'] == 'Not Sold'): 
        merged_df.loc[i, 'Hammer Price'] = 0.0
    
merged_df['Hammer Price'] = pd.to_numeric(merged_df['Hammer Price'], errors='coerce')

# %%
merged_df.drop(['Size', 'Medium'], inplace=True, axis=1)

# %%
means = []

for i, row in merged_df.iterrows():
    mean = (row['Low Estimation Price'] + row['High Estimation Price']) / 2
    means.append(mean)
    if(row['Hammer Price'] == 0.0): 
        merged_df.loc[i, 'Hammer Price'] = mean


# 
merged_df['Mean Estimation'] = pd.Series(means)

# %%
# print(merged_df.loc[:,"Mean Estimation"])
merged_df.head()
# Out:
#      ID                           Path                Artist  \
# 0  67.0  Impression_Expression/67.JPEG          Errol Boyley
# 1  59.0  Impression_Expression/59.JPEG  Richard Hayley Lever
# 2  16.0  Impression_Expression/16.JPEG      Blessing Ngobeni
# 3  58.0  Impression_Expression/58.JPEG       Adriaan Boshoff
# 4  17.0  Impression_Expression/17.JPEG         David Koloane
#
#    Low Estimation Price  High Estimation Price  Hammer Price  Mean Estimation
# 0                 810.0                 1080.0         918.0            945.0
# 1                 540.0                  810.0         864.0            675.0
# 2                 810.0                 1080.0         810.0            945.0
# 3                1620.0                 2160.0        1620.0           1890.0
# 4                 540.0                  810.0         648.0            675.0

# %%
# merged_df = merged_df.drop(["Size", "Medium" ],  axis=1)

merged_df
# Out:
#       ID                           Path                Artist  \
# 0   67.0  Impression_Expression/67.JPEG          Errol Boyley
# 1   59.0  Impression_Expression/59.JPEG  Richard Hayley Lever
# 2   16.0  Impression_Expression/16.JPEG      Blessing Ngobeni
# 3   58.0  Impression_Expression/58.JPEG       Adriaan Boshoff
# 4   17.0  Impression_Expression/17.JPEG         David Koloane
# ..   ...                            ...                   ...
# 82   5.0   Impression_Expression/5.JPEG          Frans Oerder
# 83  63.0  Impression_Expression/63.JPEG       Zacharias Eloff
# 84  18.0  Impression_Expression/18.JPEG  Gordon Frank Vorster
# 85  69.0  Impression_Expression/69.JPEG  Robert Gwelo Goodman
# 86  57.0  Impression_Expression/57.JPEG       Christiaan Nice
#
#     Low Estimation Price  High Estimation Price  Hammer Price  Mean Estimation
# 0                  810.0                 1080.0         918.0            945.0
# 1                  540.0                  810.0         864.0            675.0
# 2                  810.0                 1080.0         810.0            945.0
# 3                 1620.0                 2160.0        1620.0           1890.0
# 4                  540.0                  810.0         648.0            675.0
# ..                   ...                    ...           ...              ...
# 82                1620.0                 2700.0        2052.0           2160.0
# 83                1080.0                 1620.0        2430.0           1350.0
# 84                 324.0                  486.0         405.0            405.0
# 85                 648.0                  972.0         648.0            810.0
# 86                 432.0                  648.0         702.0            540.0
#
# [87 rows x 7 columns]

# %% [markdown]
# # 1.4 Creating Compressed files to hold data

# %%
# from sklearn.preprocessing import LabelEncoder

# merged_df['Artist'].unique()

# le = LabelEncoder()

# artistLE = le.fit_transform(merged_df['Artist'])
# artistLabels = le.classes_


# artistLabels = np.array(artistLabels).ravel()


# artistLabels.shape


# labelEncoer_df = pd.DataFrame(artistLE, columns = artistLabels)

# # oneHot_df.head()

# %%
##Creating List for Compressed Numpy array data paths
npz_paths = []

IMAGE_RESIZE = (256,256)
# merged_df = merged_df.reset_index(drop=True)

for i, row in merged_df.iterrows():

    ## ASsigning iamge path the picture path
    picture_Path = row['Path']

    ## Creating NPZ Path 
    npz_path = picture_Path.split('.')[0] + '.npz'
    npz_paths.append(npz_path)

    ## Loading Image from picture path
    pic_bgr_arr = cv2.imread(picture_Path)
    pic_rgb_arr = cv2.cvtColor(pic_bgr_arr, cv2.COLOR_BGR2RGB)
    pic_rgb_arr = cv2.resize(pic_rgb_arr, IMAGE_RESIZE)

    ## assigning Artist col
    artist = np.array(row['Artist']).astype(str)


    lowEst = np.array( row['Low Estimation Price']).astype(int)
    highEst = np.array( row['High Estimation Price']).astype(int)
    hmrPrc = np.array( row['Hammer Price']).astype(int)
    
    features = np.array([lowEst, highEst, hmrPrc]).astype(int)
   
    meanEst = np.array(row['Mean Estimation'] ).astype(int)
    
    np.savez_compressed(npz_path, pic=pic_rgb_arr, artist=artist, features=features, meanEst=meanEst)
    
merged_df['NPZ_Path'] = pd.Series(npz_paths)


    

print(merged_df.head())
# print(merged_df.tail())
# Out:
#      ID                           Path                Artist  \
# 0  67.0  Impression_Expression/67.JPEG          Errol Boyley
# 1  59.0  Impression_Expression/59.JPEG  Richard Hayley Lever
# 2  16.0  Impression_Expression/16.JPEG      Blessing Ngobeni
# 3  58.0  Impression_Expression/58.JPEG       Adriaan Boshoff
# 4  17.0  Impression_Expression/17.JPEG         David Koloane
#
#    Low Estimation Price  High Estimation Price  Hammer Price  Mean Estimation  \
# 0                 810.0                 1080.0         918.0            945.0
# 1                 540.0                  810.0         864.0            675.0
# 2                 810.0                 1080.0         810.0            945.0
# 3                1620.0                 2160.0        1620.0           1890.0
# 4                 540.0                  810.0         648.0            675.0
#
#                        NPZ_Path
# 0  Impression_Expression/67.npz
# 1  Impression_Expression/59.npz
# 2  Impression_Expression/16.npz
# 3  Impression_Expression/58.npz
# 4  Impression_Expression/17.npz

# %% [markdown]
# # Dont Really Need the NPZ Files, honeslt.y such was unless wanted data that does not include images

# %%
inputs_df = merged_df
inputs_df.head()

inputs_df.drop(['Path', "NPZ_Path"], inplace=True, axis=1)
#

# %%
# loadNPZ = np.load('Impression_Expression/0.npz ')

# img = loadNPZ['pic']
# artistName = loadNPZ['artist']
# features = loadNPZ['features']


# print(features, loadNPZ['meanEst'])

# plt.imshow(img)


images = []
for i, row in inputs_df.iterrows():
    # Generate data with a range nthat varies from one plot to the next.
    currPath = row['ID']
    npz_loadPath = np.load('Impression_Expression/' + str(int(currPath)) + '.npz')
    image = npz_loadPath['pic']
    images.append(image)
    plt.imshow(images[i])
    
inputs_df['Images'] = pd.Series(images)

# %%
# ""'from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# inputs_df.unique()


le = LabelEncoder()

inputs_df['Artist'] = le.fit_transform(inputs_df['Artist'])
# # artistLabels = np.array(artistLabels).ravel()


# artistLabels = ohe.categories_

# %%
inputs_df.head()
# Out:
#      ID  Artist  Low Estimation Price  High Estimation Price  Hammer Price  \
# 0  67.0      20                 810.0                 1080.0         918.0
# 1  59.0      39                 540.0                  810.0         864.0
# 2  16.0       7                 810.0                 1080.0         810.0
# 3  58.0       0                1620.0                 2160.0        1620.0
# 4  17.0      16                 540.0                  810.0         648.0
#
#    Mean Estimation                                             Images
# 0            945.0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 1            675.0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 2            945.0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 3           1890.0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 4            675.0  [[[255, 255, 255], [255, 255, 255], [255, 255,...

# %%
#  oneHot_df = pd.DataFrame(artistOHE, columns = artistLabels)

#  oneHot_df.head()

# %%
def swap_columns(df, col1, col2):
    col_list = list(df.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    df = df[col_list]
    return df

inputs_df.head()
# Out:
#      ID  Artist  Low Estimation Price  High Estimation Price  Hammer Price  \
# 0  67.0      20                 810.0                 1080.0         918.0
# 1  59.0      39                 540.0                  810.0         864.0
# 2  16.0       7                 810.0                 1080.0         810.0
# 3  58.0       0                1620.0                 2160.0        1620.0
# 4  17.0      16                 540.0                  810.0         648.0
#
#    Mean Estimation                                             Images
# 0            945.0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 1            675.0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 2            945.0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 3           1890.0  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 4            675.0  [[[255, 255, 255], [255, 255, 255], [255, 255,...

# %%
pic = random.randint(0, len(inputs_df))
picture = inputs_df.loc[pic, 'Images']
plt.imshow(picture)


#     plt.imshow(picture)

# %%
inputs_df.dtypes
# Out:
# ID                       float64
# Artist                     int64
# Low Estimation Price     float64
# High Estimation Price    float64
# Hammer Price             float64
# Mean Estimation          float64
# Images                    object
# dtype: object

# %% [markdown]
# # 1.? - Normalize the data

# %%
maxLow = inputs_df['Low Estimation Price'].max()
lowStd = inputs_df['Low Estimation Price'].std()

maxHigh = inputs_df['High Estimation Price'].max()
highStd = inputs_df['High Estimation Price'].std()

maxEst = inputs_df['Mean Estimation'].max()
estStd = inputs_df['Mean Estimation'].std()

maxSale = inputs_df['Hammer Price'].max()
saleStd = inputs_df['Hammer Price'].std()

maxLow, lowStd, maxHigh, highStd, maxEst, estStd, maxSale, saleStd
# Out:
# (81000.0,
#  8769.692331011014,
#  97200.0,
#  10696.703601983038,
#  89100.0,
#  9725.953371787076,
#  89100.0,
#  9600.474084960932)

# %% [markdown]
# # 2 - Normalizing data

# %%
for i in range(len(inputs_df)):
    inputs_df.loc[i, 'Low Estimation Price'] = inputs_df.at[i, 'Low Estimation Price'] / maxLow
    inputs_df.loc[i, 'High Estimation Price'] = inputs_df.at[i, 'High Estimation Price'] / maxHigh
    inputs_df.loc[i, 'Mean Estimation'] = inputs_df.at[i, 'Mean Estimation'] / maxEst
    inputs_df.loc[i, 'Hammer Price'] = inputs_df.at[i, 'Hammer Price'] / maxSale

# %%
# inputs_df.drop(["ID"],inplace=True, axis=1)
inputs_df.head()
    # npz_path = picture_Path.split('.')[0] + '.npz'
    # npz_paths.append(npz_path)
# Out:
#      ID  Artist  Low Estimation Price  High Estimation Price  Hammer Price  \
# 0  67.0      20              0.010000               0.011111      0.010303
# 1  59.0      39              0.006667               0.008333      0.009697
# 2  16.0       7              0.010000               0.011111      0.009091
# 3  58.0       0              0.020000               0.022222      0.018182
# 4  17.0      16              0.006667               0.008333      0.007273
#
#    Mean Estimation                                             Images
# 0         0.010606  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 1         0.007576  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 2         0.010606  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 3         0.021212  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 4         0.007576  [[[255, 255, 255], [255, 255, 255], [255, 255,...

# %%
# swap_columns(inputs_df, 'One Hot', 'Mean Estimation')

# %%
inputs_df.drop(['ID'], inplace=True, axis=1)
# inputs_df

# %%
# print(features_df.tail())

inputs_df.reset_index(drop=True)

shuffled_df = inputs_df.sample(frac=1)

train_df, val_df, test_df = shuffled_df[:60], shuffled_df[60:80], shuffled_df[80:]

len(train_df), len(val_df), len(test_df)
# train_df["Artist"].dtypes
# Out:
# (60, 20, 7)

# %% [markdown]
# # 3 - Loading in the Data

# %%
def get_X_y(df):

    dfArr = np.array(df)

    X_pic, X_features = [], []
    y = []

    for i in range(len(df)): 

        pic = dfArr[i, 5]
        X_pic.append(pic)

        features = dfArr[i,:4]
        X_features.append(features)

        # artit = df['Artist']
        # print(artit)

        # X_artist.append(artit)

        Estimate = dfArr[0,4]
        y.append(Estimate)

    X_pic, X_features = np.asarray(X_pic), np.asarray(X_features)
    y = np.asarray(y)

    return (X_pic, X_features), y

# %%
(X_train_pic, X_train_features), y_train = get_X_y(train_df)

(X_val_pic, X_val_features), y_val = get_X_y(val_df)

(X_test_pic, X_test_features), y_test = get_X_y(test_df)

# %%
X_train_pic.shape, X_train_features.shape, y_train.shape
# Out:
# ((60, 256, 256, 3), (60, 4), (60,))

# %%
# train_df.dtypes

plt.imshow(X_train_pic[1])

# %% [markdown]
# # 4 - Model Architecture

# %%
# create the MLP and CNN models
# Keras: Multiple Inputs and Mixed Data
# import the necessary packages

from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import concatenate
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np
import argparse
import locale
import os

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# %%
## Define the CNN Model


input_pic = layers.Input(shape=(256,256,3))
x = layers.Lambda(preprocess_input)(input_pic)
x = MobileNetV2(input_shape=(256,256,3), include_top=False)(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(10, activation='relu')(x)
x = Model(inputs=input_pic, outputs=x)


### Feed foward the stream
input_features = layers.Input(shape=(4,))
y = layers.Dense(32, activation='relu')(input_features)
y = layers.Dense(10, activation='relu')(y)
y = Model(inputs=input_features, outputs=y)

## Concatenate

combined = layers.concatenate([x.output, y.output])

z = layers.Dense(4, activation='relu')(combined)
z = layers.Dense(1, activation='linear')(z)

model = Model(inputs=[x.input, y.input],outputs=z)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 256, 256, 3  0           []
#                                 )]
#
#  lambda_5 (Lambda)              (None, 256, 256, 3)  0           ['input_12[0][0]']
#
#  mobilenetv2_1.00_224 (Function  (None, 8, 8, 1280)  2257984     ['lambda_5[0][0]']
#  al)
#
#  input_14 (InputLayer)          [(None, 4)]          0           []
#
#  global_average_pooling2d_4 (Gl  (None, 1280)        0           ['mobilenetv2_1.00_224[0][0]']
#  obalAveragePooling2D)
#
#  dense_11 (Dense)               (None, 32)           160         ['input_14[0][0]']
#
#  dense_10 (Dense)               (None, 10)           12810       ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_12 (Dense)               (None, 10)           330         ['dense_11[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 20)           0           ['dense_10[0][0]',
#                                                                   'dense_12[0][0]']
#
#  dense_13 (Dense)               (None, 4)            84          ['concatenate_2[0][0]']
#
#  dense_14 (Dense)               (None, 1)            5           ['dense_13[0][0]']
#
# ==================================================================================================
# Total params: 2,271,373
# Trainable params: 2,237,261
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
optimzer = Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=optimzer, metrics=['mean_absolute_error', 'accuracy'])

cp = ModelCheckpoint('model/', save_best_only=True)

# %%
logdir = 'logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
X_train_featuresTensor = tf.convert_to_tensor(X_train_features, dtype="float32")
X_train_picTensor = tf.convert_to_tensor(X_train_pic, dtype="float32")

y_trainTensor = tf.convert_to_tensor(y_train, dtype="float32")

X_val_featuresTensor = tf.convert_to_tensor(X_val_features, dtype="float32")
X_val_picTensor = tf.convert_to_tensor(X_val_pic, dtype="float32")

y_valTensor = tf.convert_to_tensor(y_val, dtype="float32")

X_test_featuresTensor = tf.convert_to_tensor(X_test_features, dtype="float32")
X_test_picTensor = tf.convert_to_tensor(X_test_pic, dtype="float32")

y_testTensor = tf.convert_to_tensor(y_test, dtype="float32")

# %%
model.fit(x=[X_train_picTensor, X_train_featuresTensor], y=y_train,
          validation_data=([X_val_picTensor, X_val_featuresTensor], y_valTensor), 
          epochs=10, 
          callbacks=[cp])
# Out:
# Epoch 1/10
# 2/2 [==============================] - ETA: 0s - loss: 0.7992 - mean_absolute_error: 0.7089 - accuracy: 0.0000e+00
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# 2/2 [==============================] - 50s 32s/step - loss: 0.7992 - mean_absolute_error: 0.7089 - accuracy: 0.0000e+00 - val_loss: 0.8542 - val_mean_absolute_error: 0.7964 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 2/2 [==============================] - ETA: 0s - loss: 0.4706 - mean_absolute_error: 0.4841 - accuracy: 0.0000e+00
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# 2/2 [==============================] - 34s 28s/step - loss: 0.4706 - mean_absolute_error: 0.4841 - accuracy: 0.0000e+00 - val_loss: 0.5510 - val_mean_absolute_error: 0.6600 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 2/2 [==============================] - 10s 5s/step - loss: 0.2125 - mean_absolute_error: 0.3368 - accuracy: 0.0000e+00 - val_loss: 4.0548 - val_mean_absolute_error: 1.9226 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 2/2 [==============================] - 10s 5s/step - loss: 0.0962 - mean_absolute_error: 0.2155 - accuracy: 0.0000e+00 - val_loss: 7.0213 - val_mean_absolute_error: 2.5081 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 2/2 [==============================] - 10s 5s/step - loss: 0.0314 - mean_absolute_error: 0.1155 - accuracy: 0.0000e+00 - val_loss: 8.5825 - val_mean_absolute_error: 2.7236 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 2/2 [==============================] - 10s 5s/step - loss: 0.0100 - mean_absolute_error: 0.0684 - accuracy: 0.0000e+00 - val_loss: 9.2115 - val_mean_absolute_error: 2.7528 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 2/2 [==============================] - 10s 5s/step - loss: 0.0198 - mean_absolute_error: 0.0721 - accuracy: 0.0000e+00 - val_loss: 8.2610 - val_mean_absolute_error: 2.4906 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 2/2 [==============================] - 10s 5s/step - loss: 0.0076 - mean_absolute_error: 0.0511 - accuracy: 0.0000e+00 - val_loss: 6.3431 - val_mean_absolute_error: 2.1221 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 2/2 [==============================] - 10s 5s/step - loss: 0.0074 - mean_absolute_error: 0.0515 - accuracy: 0.0000e+00 - val_loss: 5.0611 - val_mean_absolute_error: 1.8751 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 2/2 [==============================] - 9s 5s/step - loss: 0.0042 - mean_absolute_error: 0.0429 - accuracy: 0.0000e+00 - val_loss: 4.1511 - val_mean_absolute_error: 1.7125 - val_accuracy: 0.0000e+00

# %%
loaded_model = load_model('model/')

# %%
test_predictions = loaded_model.predict([X_test_picTensor, X_test_featuresTensor]).flatten()
# Out:
# 1/1 [==============================] - 1s 869ms/step

# %%
testPred = pd.Series(test_predictions)

# %%
testPred.hist()
# Out:
# <Axes: >

# %%
test_df.reset_index(drop=True, inplace=True)
test_df['Predicted Estimate'] = testPred
# Out:
# <ipython-input-190-cbfb01551e17>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Predicted Estimate'] = testPred
# <ipython-input-190-cbfb01551e17>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df.drop(['Images'], inplace=True, axis=1)

# %%
# test_df.drop(['Images'], inplace=True, axis=1)
test_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dddd0b70a4eb> in <cell line: 2>()
#       1 # test_df.drop(['Images'], inplace=True, axis=1)
# ----> 2 test_df.head()
#
# NameError: name 'test_df' is not defined

# %%
logdir = 'logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
# hist = model.fit(x=[X_train_featuresTensor, X_train_picTensor], epochs=20, validation_data=[X_val_featuresTensor, X_val_picTensor], callbacks=[tensorboard_callback])

# %%
# fig = plt.figure()
# plt.plot(hist.model['loss'], color='teal', label='loss')
# plt.plot(hist.model['val_loss'], color='orange', label='val_loss')
# fig.suptitle('Loss', fontsize=20)
# plt.legend(loc='upper left')
# plt.show()

# %%
# for i in range(len(preds)): 
#     pred = preds[i]*maxEst
#     print("Prediction: ", pred)

# y_test
